# %%
import numpy as np
import matplotlib.pyplot as plt

x1 = np.random.random((30,2))*3 + 10
# x1 = np.insert(x1, 2, 1, axis = 1)
x2 = np.random.random((30,2))*3 + 15
# x2 = np.insert(x2, 2, -1, axis = 1)

plt.scatter(x1[:,0],x1[:,1])
plt.scatter(x2[:,0],x2[:,1])

# %%
print(x1)
print(x1[1])
# Out:
# [[11.56129499 12.05828586]
#  [10.6183448  12.68746306]
#  [11.52283538 12.33586905]
#  [12.48224198 10.22555261]
#  [11.98191384 12.14241284]
#  [12.03907633 12.0173544 ]
#  [10.50691957 11.41653322]
#  [12.19768859 11.87673501]
#  [10.54557884 11.34317926]
#  [10.29744707 10.01682404]
#  [11.35398407 10.43593956]
#  [10.48602531 10.27233624]
#  [12.56897224 10.50105414]
#  [12.05120572 12.5907176 ]
#  [12.41447735 12.78947515]
#  [12.77235802 10.67520815]
#  [11.31061925 12.03466702]
#  [10.14375599 11.91768551]
#  [10.21089668 12.94888953]
#  [11.79726157 11.98602942]
#  [12.89195019 11.37172004]
#  [10.8555516  12.95339506]
#  [12.1215942  10.89057483]
#  [10.60207228 11.62944598]
#  [12.69618119 11.7922174 ]
#  [10.20953612 11.49353147]
#  [12.37719153 11.25188616]
#  [10.23003324 11.37166576]
#  [12.87329523 11.31665217]
#  [10.63168781 11.67600934]]
# [10.6183448  12.68746306]

# %%
N1 = 30
u1 = np.mean(x1, axis = 0)
u1 = np.mat(u1)
u2 = np.mean(x2, axis = 0)
u2 = np.mat(u2)
cov1 = np.cov(x1[:,0], x1[:,1])
cov2 = np.cov(x2[:,0], x2[:,1])
S_w = cov1 + cov2
S_b = (u1-u2).T*(u1-u2)
S_w = np.mat(S_w)
a,b = np.linalg.eig(S_w.I*S_b)
print(a)
w = S_w.I*(u1 - u2).T
x11 = np.mat(x1)
x22 = np.mat(x2)
k = w[1]/w[0]
plt.figure()
plt.scatter(x1[:,0],x1[:,1])
plt.scatter(x2[:,0],x2[:,1])
plt.plot([9,19],[9,9+10*k],'k')
plt.show()
# Out:
# [ 0.         43.47429484]
